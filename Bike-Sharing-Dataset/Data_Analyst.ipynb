# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# Nama: Fauzi Ramadhan
# Email: fauzir008@gmail.com
# Id Dicoding: fauzi_ramadhan_ujcf

# %% [markdown]
# # Menentukan Pertanyaan Bisnis
#
# ### Pertanyaan 1:
# "Bagaimana tren peminjaman sepeda berdasarkan hari dalam satu tahun, dan apa hubungannya dengan cuaca?"
#
# ### Pertanyaan 1:
# "Apa pengaruh cuaca (misalnya, hujan, mendung, cerah) terhadap peminjaman sepeda pada hari kerja dan akhir pekan?"

# %%
# Menyiapkan semua library yang dibutuhkan
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install streamlit
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
# ...

# %%
# Data Wrangling

# Gathering Data
import pandas as pd

# Memuat dataset day.csv
day_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/day.csv')

# Memeriksa lima baris pertama dataset day.csv
print(day_data.head(28))

# Memuat dataset hour.csv
hour_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/hour.csv')

# Memeriksa lima baris pertama dataset hour.csv
print(hour_data.head(28))
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1        0        6           0
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# ...

# %%
# Data Wrangling

### Assessing Data
import pandas as pd

# Memuat dataset day.csv
day_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/day.csv')

# Memeriksa informasi dasar tentang dataset day.csv
print("Info dataset day.csv:")
print(day_data.info())

# Memeriksa jumlah data yang hilang (missing values) pada dataset day.csv
missing_data_day = day_data.isnull().sum()
print("\nJumlah data yang hilang pada dataset day.csv:")
print(missing_data_day)

# Memuat dataset hour.csv
hour_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/hour.csv')

# Memeriksa informasi dasar tentang dataset hour.csv
print("\nInfo dataset hour.csv:")
print(hour_data.info())

# Memeriksa jumlah data yang hilang (missing values) pada dataset hour.csv
missing_data_hour = hour_data.isnull().sum()
print("\nJumlah data yang hilang pada dataset hour.csv:")
print(missing_data_hour)
# Out:
# Info dataset day.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None
#
# ...

# %%
# Data Wrangling

### Cleaning Data
import pandas as pd

# Memuat dataset day.csv
day_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/day.csv')

# Memeriksa data yang hilang atau tidak sesuai
print("Informasi dataset day.csv sebelum cleaning:")
print(day_data.info())

# Langkah 1: Mengatasi data yang hilang (missing values)
# Dalam contoh ini, kita akan menghapus baris yang mengandung data yang hilang
day_data = day_data.dropna()

# Langkah 2: Mengatasi data yang tidak sesuai
# Dalam contoh ini, kita akan memastikan tipe data kolom yang sesuai

# Konversi kolom 'dteday' ke tipe data datetime
day_data['dteday'] = pd.to_datetime(day_data['dteday'])

# Memeriksa informasi dataset setelah cleaning
print("\nInformasi dataset day.csv setelah cleaning:")
print(day_data.info())

# Memuat dataset hour.csv
hour_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/hour.csv')

# Memeriksa data yang hilang atau tidak sesuai
print("\nInformasi dataset hour.csv sebelum cleaning:")
print(hour_data.info())

# Langkah 1: Mengatasi data yang hilang (missing values)
# Dalam contoh ini, kita akan menghapus baris yang mengandung data yang hilang
hour_data = hour_data.dropna()

# Langkah 2: Mengatasi data yang tidak sesuai
# Dalam contoh ini, kita akan memastikan tipe data kolom yang sesuai

# Konversi kolom 'dteday' dan 'hr' ke tipe data datetime
hour_data['dteday'] = pd.to_datetime(hour_data['dteday'])
hour_data['hr'] = hour_data['hr'].astype('int')

# Memeriksa informasi dataset setelah cleaning
print("\nInformasi dataset hour.csv setelah cleaning:")
print(hour_data.info())
# Out:
# Informasi dataset day.csv sebelum cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None
#
# ...

# %%
## Exploratory Data Analysis (EDA)

#### Explore ...
import pandas as pd
import matplotlib.pyplot as plt

# Memuat dataset day.csv
day_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/day.csv')

# Statistik Deskriptif
print("Statistik Deskriptif untuk Jumlah Peminjaman Sepeda (cnt):")
print(day_data['cnt'].describe())

# Visualisasi Jumlah Peminjaman Sepeda harian
plt.figure(figsize=(10, 6))
plt.plot(day_data['dteday'], day_data['cnt'], marker='o', color='b', label='Peminjaman Sepeda')
plt.title('Jumlah Peminjaman Sepeda Harian')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# Korelasi antara suhu rata-rata dan jumlah peminjaman sepeda
correlation = day_data['temp'].corr(day_data['cnt'])
print(f"Korelasi antara Suhu Rata-rata dan Jumlah Peminjaman Sepeda: {correlation}")

# Memuat dataset hour.csv
hour_data = pd.read_csv('C:/Data Science/Dataset_Proyek/Bike-Sharing-Dataset/hour.csv')

# Statistik Deskriptif
print("Statistik Deskriptif untuk Jumlah Peminjaman Sepeda (cnt):")
print(hour_data['cnt'].describe())

# Visualisasi Jumlah Peminjaman Sepeda per Jam
plt.figure(figsize=(12, 6))
plt.plot(hour_data['hr'], hour_data['cnt'], marker='o', color='g', label='Peminjaman Sepeda')
plt.title('Jumlah Peminjaman Sepeda per Jam')
plt.xlabel('Jam dalam Sehari')
plt.ylabel('Jumlah Peminjaman')
plt.grid(True)
plt.legend()
plt.show()

# Korelasi antara suhu rata-rata dan jumlah peminjaman sepeda
correlation = hour_data['temp'].corr(hour_data['cnt'])
print(f"Korelasi antara Suhu Rata-rata dan Jumlah Peminjaman Sepeda: {correlation}")
# Out:
# Statistik Deskriptif untuk Jumlah Peminjaman Sepeda (cnt):
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64
# Korelasi antara Suhu Rata-rata dan Jumlah Peminjaman Sepeda: 0.6274940090334918
# Statistik Deskriptif untuk Jumlah Peminjaman Sepeda (cnt):
# count    17379.000000
# mean       189.463088
# std        181.387599
# min          1.000000
# 25%         40.000000
# 50%        142.000000
# 75%        281.000000
# max        977.000000
# Name: cnt, dtype: float64
# Korelasi antara Suhu Rata-rata dan Jumlah Peminjaman Sepeda: 0.4047722757786586

# %%
## Visualization & Explanatory Analysis
import pandas as pd
import matplotlib.pyplot as plt

### Pertanyaan 1:
- Bagaimana pola peminjaman sepeda berubah sepanjang tahun pada dataset day.csv?

# Visualisasi Jumlah Peminjaman Sepeda Harian sepanjang Tahun
plt.figure(figsize=(12, 6))
plt.plot(day_data['dteday'], day_data['cnt'], marker='o', color='b', label='Peminjaman Sepeda')
plt.title('Jumlah Peminjaman Sepeda Harian sepanjang Tahun')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

### Pertanyaan 2:
- Bagaimana pengaruh cuaca (misalnya, cuaca cerah, mendung, hujan) terhadap peminjaman sepeda pada dataset hour.csv?

# Analisis pengaruh cuaca terhadap peminjaman sepeda
plt.figure(figsize=(10, 6))
sns.boxplot(x='weathersit', y='cnt', data=hour_data, palette='Set2')
plt.title('Pengaruh Cuaca terhadap Jumlah Peminjaman Sepeda')
plt.xlabel('Cuaca')
plt.ylabel('Jumlah Peminjaman')
plt.grid(True)
plt.show()
# Out:
# Object `day.csv` not found.
# Object `hour.csv` not found.

# %% [markdown]
# ## Conclusion
#
# - Conclution pertanyaan 1
# Pola peminjaman sepeda harian pada dataset day.csv menunjukkan tren yang cenderung naik selama setahun dengan fluktuasi musiman. Peminjaman sepeda puncak terjadi pada musim panas dan jumlahnya lebih rendah selama musim dingin.
# - conclution pertanyaan 2
# Analisis menunjukkan bahwa cuaca memiliki pengaruh yang signifikan terhadap peminjaman sepeda pada dataset hour.csv. Peminjaman sepeda lebih tinggi pada hari dengan cuaca cerah atau mendung, sedangkan peminjaman cenderung lebih rendah pada hari hujan.
