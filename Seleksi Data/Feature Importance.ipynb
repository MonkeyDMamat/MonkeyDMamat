# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:/MK Semester 4/Data Mining/train.csv")

X = data.iloc[:,0:20]
y = data.iloc[:,-1]

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

model = ExtraTreesClassifier()
model.fit(X,y)

print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_,index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.06220216 0.02046829 0.03252598 0.01906147 0.03293856 0.01642213
#  0.03528536 0.0330589  0.03601821 0.03233376 0.03315135 0.04708986
#  0.04797498 0.39502356 0.03392978 0.0338971  0.03524826 0.01451156
#  0.01918832 0.01967038]
